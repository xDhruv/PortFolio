# %% [markdown]
# # **Machine Learning:**

# %% [markdown]
# ## **About the Data:**
#
# Zomato is an Indian multinational restaurant aggregator and food delivery
# company founded by Deepinder Goyal and Pankaj Chaddah in 2008. Zomato
# provides information, menus, and user reviews of restaurants as well as food
# delivery options from partner restaurants in select cities.
#
# ## **Attributes:**
#
# 1. URL - Website of the Zomato for each restaurant. - Object datatype
# 2. Address - Address of the Restaurant. - Object datatype
# 3. Name - Name of the restaurant. - Object datatype
# 4. Online Order - The customer ordered the menu online or not. - Object datatype
# 5. Book table - The customer has booked the table or not. - Object datatype
# 6. Rate - Rating of the restaurant that has by the customer. - Numerical datatype
# 7. Votes - The votes have been given by the customer to the restaurant. - Numerical
# datatype
# 8. Phone - Contact number of the Restaurant. - Object datatype
# 9. Location - The city name where the restaurant is located. - Object datatype
# 10. Rest Type - The type of restaurant. - Object datatype
# 11. Dish liked - Dishes liked by the customer from the restaurant. - Object datatype
# 12. Cuisines - The cuisines that have been prepared by the restaurant. - Object datatype
# 13. Approx Cost for two people - The approximate cost of the customer for 2 people. -
# Number datatype
# 14. Reviews list - The reviews made by the customers on the restaurant. - Object
# datatype
# 15. Menu Item - The menu items that are usually available at the restaurant. - Object
# datatype
# 16. Listed in (type) - Contains the type of the meal. - Object datatype
# 17. Listed in (city) - This contains the neighborhood in which the restaurant is listed. -
# Object datatype

# %% [markdown]
# # **Section A**

# %% [markdown]
# ## **Title: Regression Model**
#
# ### **Problem Statement:**
#
# Restaurants from all over the world can be found here in Bengaluru. From the United States to Japan, Russia to Antarctica, you get all types of cuisines here. Delivery, Dine-out, Pubs, Bars, Drinks, Buffet, Desserts you name it and Bengaluru has it. Bengaluru is the best place for foodies. The number of restaurants is increasing day by day. Currently, it stands at approximately 12,000 restaurants. With such a high number of restaurants. This industry hasn't been saturated yet. And new restaurants are opening every day. However, it has become difficult for them to compete with already established restaurants. The key issues that continue to pose a challenge to them include high real estate costs, rising food costs, shortage of quality manpower, fragmented supply chain, and over-licensing.
#
# ### **Objective:**
#
# The newly started companies are not able to decide the cost that would happen per two people for once. So the Zomato company has a good analyst team who can predict the cost per two customers for one time so that the newly started  restaurants and upcoming restaurants will be well prepared how the restaurant should invest in improving the ambiance and all other stuff to attract the customers. Assume you are the analyst team that Zomato has organized to help new and upcoming restaurants by letting them know the various reasons that customers look for and build a model which able to predict the cost for two people.
#
# ### **Steps that are to be followed:**
#
# **Step 1:** Understand the business problem.
#
# **Step 2:** Read the data, and convert the data types.
#
#     Note: The data set has numerical and categorical data but due to noise(anomaly) in the data, the columns
#     are treated as the object type. And You may feel like converting the features into numerical at this step
#     if not appropriate at this stage, In that case, feel free to convert the variable to the appropriate type
#     in the further step as well based on your way of analyzing the data.
#
# **Step 3:** Perform the described method for the data, Try to find any essential points from the described analysis. And check the missing values and Duplicate records. Impute the missing values in the best way possible.
#
#     Note: To impute the missing values with parameters, you must find the best parameter.
#
# **Hint:** Check the distribution using plots. And check the Skewness, Kurtosis and etc.
#
# **Step 4:** Once the basic preprocessing is done like converting the data types, missing value imputation, and duplicate rows. perform the EDA (Exploratory Data Analysis) on the data to find the various factors that will help to understand the cost per two persons.
#
# **Step 5:** Make a copy of the data set and Perform the preprocessing that require for the model.
#
#     Note: You can see many categorical variables with a high number of unique values. Therefore do not keep dropping
#     the variables as the first option, try to create new variables or perform any other feature engineering methods.
#
# **Step 6:** Perform statistical hypothesis testing on features to get an idea of whether features are impacting the target variables.
#
# **Step 7:** Split the dataset into train and test data sets and Perform the scaling on both sets if necessary.
#
# **Step 8:** Build the base model.
#
# **Step 9:** Understand how the model is performing, Perform feature engineering again if needed. Do feature selection. Try with various models like a parametric and nonparametric models. Once you choose the final model, rebuild the model with best parameters.
#
#     Note: If you are performing with Linear models, check the model is fulfilling the assumptions.
#
# **Step 10:** Based on your understanding of the model and EDA analysis, Explain the business understanding.

# %% [markdown]
# **Importing Libraries**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')
from scipy import stats
import statistics
import statsmodels.api as sm
from scipy import stats
import statistics
from scipy.stats import shapiro
from statsmodels.stats import weightstats as stests
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from scipy.stats import chisquare
import statsmodels.stats.multicomp as mc
from sklearn import datasets, linear_model, metrics
from sklearn.model_selection import train_test_split
from statsmodels.api import add_constant
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
print('imported all libraries')
# Out:
# imported all libraries

# %% [markdown]
# **Data**

# %%
# read the data 
df_zomato = pd.read_csv('/content/drive/MyDrive/ML Mini project/zomato.csv')

# display the first five observations
df_zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
# checking shape of data 
df_zomato.shape
# Out:
# (51717, 17)

# %%
# checking datatypes of data
df_zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df=df_zomato.copy()

# %% [markdown]
# **Cleaning the data**

# %%
# dropping unwanted columns
df.drop(['name','url', 'address', 'phone','dish_liked','reviews_list','menu_item'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (51717, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   online_order                 51717 non-null  object
#  1   book_table                   51717 non-null  object
#  2   rate                         43942 non-null  object
#  3   votes                        51717 non-null  int64
#  4   location                     51696 non-null  object
#  5   rest_type                    51490 non-null  object
#  6   cuisines                     51672 non-null  object
#  7   approx_cost(for two people)  51371 non-null  object
#  8   listed_in(type)              51717 non-null  object
#  9   listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
# checking for duplicate entries
df.duplicated().sum()
# Out:
# 372

# %%
#calculating ratio of duplicated values to entire dataset
df.duplicated().sum()/df.shape[0]
# Out:
# 0.007192992632983352

# %%
# dropping duplicate rows
df = df.drop_duplicates()                                        

# checking shape of data after dropping duplicates
df.shape
# Out:
# (51345, 10)

# %%
# checking column names
df.columns
# Out:
# Index(['online_order', 'book_table', 'rate', 'votes', 'location', 'rest_type',
#        'cuisines', 'approx_cost(for two people)', 'listed_in(type)',
#        'listed_in(city)'],
#       dtype='object')

# %%
#renaming some columns for better understanding
df.rename(columns = {'approx_cost(for two people)':'cost', 'listed_in(type)':'service', 'listed_in(city)':'city'}, inplace=True)

# %%
df.columns
# Out:
# Index(['online_order', 'book_table', 'rate', 'votes', 'location', 'rest_type',
#        'cuisines', 'cost', 'service', 'city'],
#       dtype='object')

# %%
# checking for missing values
df.isnull().sum()
# Out:
# online_order       0
# book_table         0
# rate            7520
# votes              0
# location          19
# rest_type        225
# cuisines          43
# cost             341
# service            0
# city               0
# dtype: int64

# %%
# # checking for missing values in 'location' column
df[df.location.isnull()]
# Out:
#       online_order book_table rate  votes location rest_type cuisines cost  \
# 1662            No         No  NaN      0      NaN       NaN      NaN  NaN
# 9874            No         No  NaN      0      NaN       NaN      NaN  NaN
# 13693           No         No  NaN      0      NaN       NaN      NaN  NaN
# 16351           No         No  NaN      0      NaN       NaN      NaN  NaN
# 26432           No         No  NaN      0      NaN       NaN      NaN  NaN
# 26519           No         No  NaN      0      NaN       NaN      NaN  NaN
# 27672           No         No  NaN      0      NaN       NaN      NaN  NaN
# 28611           No         No  NaN      0      NaN       NaN      NaN  NaN
# 29298           No         No  NaN      0      NaN       NaN      NaN  NaN
# 30604           No         No  NaN      0      NaN       NaN      NaN  NaN
# 31400           No         No  NaN      0      NaN       NaN      NaN  NaN
# ...

# %%
# # getting index of all rows having missing value in 'location' column
indexLocation = df[df.location.isnull()].index

# %%
# # dropping rows with missing value in 'location' column
df = df.drop(indexLocation)

# %%
# # checking for missing values in 'location' column
df['location'].isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (51326, 10)

# %%
# checking unique values of 'rate' column
df['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df[df['rate'] == 'NEW']
# Out:
#       online_order book_table rate  votes      location  \
# 72              No         No  NEW      0  Banashankari
# 75              No         No  NEW      0  Banashankari
# 110             No         No  NEW      0  Banashankari
# 130             No         No  NEW      0  Banashankari
# 131             No         No  NEW      0  Banashankari
# ...            ...        ...  ...    ...           ...
# 51585           No         No  NEW      0    Whitefield
# 51586          Yes         No  NEW      0    Whitefield
# 51603          Yes         No  NEW      0    Whitefield
# 51604           No         No  NEW      0    Whitefield
# 51605           No         No  NEW      0    Whitefield
#
#                      rest_type                             cuisines cost  \
# 72                 Quick Bites                         North Indian  150
# 75          Takeaway, Delivery               Street Food, Fast Food  500
# ...

# %%
df[df['rate'] == '-']
# Out:
#       online_order book_table rate  votes           location      rest_type  \
# 3068            No         No    -      0      Wilson Garden    Quick Bites
# 3069            No         No    -      0  Bannerghatta Road    Quick Bites
# 3373           Yes         No    -      0       Basavanagudi    Quick Bites
# 3378           Yes         No    -      0       Basavanagudi    Quick Bites
# 3387            No         No    -      0       Basavanagudi    Quick Bites
# ...            ...        ...  ...    ...                ...            ...
# 33454           No         No    -      0                BTM    Quick Bites
# 33463           No         No    -      0                BTM  Casual Dining
# 45646          Yes         No    -      0   Old Airport Road    Quick Bites
# 45647          Yes         No    -      0   Old Airport Road  Beverage Shop
# 48139           No         No    -      0     Residency Road           Cafe
#
# ...

# %%
df['rate'].mode()
# Out:
# 0    NEW
# Name: rate, dtype: object

# %%
df[df['rate'].isnull()]
# Out:
#       online_order book_table rate  votes      location           rest_type  \
# 84              No         No  NaN      0  Banashankari         Quick Bites
# 90              No         No  NaN      0  Banashankari            Delivery
# 91              No         No  NaN      0  Banashankari  Takeaway, Delivery
# 92              No         No  NaN      0  Banashankari                Mess
# 107             No         No  NaN      0  Banashankari  Takeaway, Delivery
# ...            ...        ...  ...    ...           ...                 ...
# 51644           No         No  NaN      0   Brookefield         Quick Bites
# 51675           No         No  NaN      0    Whitefield                 Bar
# 51710           No         No  NaN      0    Whitefield                 Bar
# 51713           No         No  NaN      0    Whitefield                 Bar
# 51714           No         No  NaN      0    Whitefield                 Bar
#
# ...

# %%
# converting datatype of 'rate' column to string 
df['rate'] = df['rate'].astype(str)

# %%
#dropping rows having 'rate' as '-' or 'NEW'
df = df[~((df['rate'] == '-') | (df['rate'] == 'NEW'))]
df.shape
# Out:
# (49086, 10)

# %%
df['rate'] = df['rate'].apply(lambda x: x.replace('/5',''))

# %%
# converting datatype of 'rate' column to float 
df['rate'] = df['rate'].astype(float)

# %%
sns.boxplot(x='rate',data=df)
# Out:
# <Axes: xlabel='rate'>

# %%
df['rate'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 2.9, 3.5, nan, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
df['rate'].isnull().sum()
# Out:
# 7501

# %%
df['rate'].mean()
# Out:
# 3.70016352050018

# %%
df['rate'].median()
# Out:
# 3.7

# %%
df['rate'] = df['rate'].fillna(df['rate'].median())

# %%
df['rate'].isnull().sum()
# Out:
# 0

# %%
df['cost'].isnull().sum()/df['cost'].shape[0]
# Out:
# 0.00645805321272868

# %% [markdown]
# As number of missing values in 'cost' column has very small ratio as compared to entire datset,we can remove these rows.

# %%
indexLocation = df[df['cost'].isnull()].index
df = df.drop(indexLocation)

# %%
df.isnull().sum()
# Out:
# online_order      0
# book_table        0
# rate              0
# votes             0
# location          0
# rest_type       202
# cuisines         19
# cost              0
# service           0
# city              0
# dtype: int64

# %%
df['cuisines'].isnull().sum()/df['cuisines'].shape[0]
# Out:
# 0.0003895917488568558

# %% [markdown]
# As number of missing values in 'cuisines' column has very small ratio as compared to entire datset,we can remove these rows.

# %%
indexLocation = df[df['cuisines'].isnull()].index
df = df.drop(indexLocation)

# %%
df['rest_type'].value_counts()
# Out:
# Quick Bites                   17698
# Casual Dining                  9990
# Cafe                           3559
# Delivery                       2446
# Dessert Parlor                 2163
#                               ...
# Dessert Parlor, Kiosk             2
# Food Court, Beverage Shop         2
# Dessert Parlor, Food Court        2
# Quick Bites, Kiosk                1
# Sweet Shop, Dessert Parlor        1
# Name: rest_type, Length: 93, dtype: int64

# %%
# checking unique values of 'rest_type' column
df['rest_type'].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', nan, 'Dhaba',
#        'Quick Bites, Sweet Shop', 'Microbrewery',
# ...

# %%
# checking for missing values in 'rest_type' column
df[df.rest_type.isnull()]
# Out:
#       online_order book_table  rate  votes           location rest_type  \
# 999            Yes         No   3.5    269                BTM       NaN
# 1300           Yes         No   3.0      7           JP Nagar       NaN
# 1376           Yes         No   3.6     15                BTM       NaN
# 1565            No         No   3.7      0  Bannerghatta Road       NaN
# 1637            No         No   2.4    392  Bannerghatta Road       NaN
# ...            ...        ...   ...    ...                ...       ...
# 50978           No         No   3.7      0         Whitefield       NaN
# 51130          Yes         No   3.7      0         Whitefield       NaN
# 51195          Yes         No   3.2    202         Whitefield       NaN
# 51294           No         No   3.7      0         Whitefield       NaN
# 51303          Yes         No   3.7      0         Whitefield       NaN
#
#                                                cuisines cost   service  \
# ...

# %%
df['rest_type'].isnull().sum()/df['rest_type'].shape[0]
# Out:
# 0.004143589743589743

# %% [markdown]
# As number of missing values in 'rest_type' column has very small ratio
#
# as compared to entire datset,we can remove these rows.

# %%
indexLocation = df[df['rest_type'].isnull()].index
df = df.drop(indexLocation)

# %%
# checking for missing values in 'rest_type' column
df['rest_type'].isnull().sum()
# Out:
# 0

# %%
# checking for missing values
df.isnull().sum()
# Out:
# online_order    0
# book_table      0
# rate            0
# votes           0
# location        0
# rest_type       0
# cuisines        0
# cost            0
# service         0
# city            0
# dtype: int64

# %% [markdown]
# Hence,all the missing values from the dataset are treated.

# %%
df['cost'] = df['cost'].str.replace(',','').astype('int')
df['cost']
# Out:
# 0         800
# 1         800
# 2         800
# 3         300
# 4         600
#          ...
# 51712    1500
# 51713     600
# 51714    2000
# 51715    2500
# 51716    1500
# Name: cost, Length: 48548, dtype: int64

# %%
df['cost'].unique()
# Out:
# array([ 800,  300,  600,  700,  550,  500,  450,  650,  400,  900,  200,
#         750,  150,  850,  100, 1200,  350,  250,  950, 1000, 1500, 1300,
#         199, 1100, 1600,  230,  130,   80,   50,  190, 1700,  180, 1350,
#        2200, 1400, 2000, 1800, 1900,  330, 2500, 2100, 3000, 2800, 3400,
#          40, 1250, 3500, 4000, 2400, 2600,  120, 1450,  469,   70, 3200,
#          60,  240, 6000, 1050, 2300, 4100, 5000, 3700, 1650, 2700, 4500,
#         140,  360])

# %%
df.head()
# Out:
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3           No         No   3.7     88  Banashankari          Quick Bites
# 4           No         No   3.8    166  Basavanagudi        Casual Dining
#
#                          cuisines  cost service          city
# 0  North Indian, Mughlai, Chinese   800  Buffet  Banashankari
# 1     Chinese, North Indian, Thai   800  Buffet  Banashankari
# 2          Cafe, Mexican, Italian   800  Buffet  Banashankari
# 3      South Indian, North Indian   300  Buffet  Banashankari
# 4        North Indian, Rajasthani   600  Buffet  Banashankari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48548 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   online_order  48548 non-null  object
#  1   book_table    48548 non-null  object
#  2   rate          48548 non-null  float64
#  3   votes         48548 non-null  int64
#  4   location      48548 non-null  object
#  5   rest_type     48548 non-null  object
#  6   cuisines      48548 non-null  object
#  7   cost          48548 non-null  int64
#  8   service       48548 non-null  object
#  9   city          48548 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 4.1+ MB

# %%
df.describe().T
# Out:
#          count        mean         std   min    25%    50%    75%      max
# rate   48548.0    3.701487    0.405196   1.8    3.5    3.7    4.0      4.9
# votes  48548.0  299.108820  823.721029   0.0    9.0   48.0  214.0  16832.0
# cost   48548.0  562.973037  444.516649  40.0  300.0  400.0  700.0   6000.0

# %% [markdown]
# Interpretation:1.For 'votes' column,mean>>median,hence,we can say that this column is highly skewed and also there is huge difference between 75% of the data and the maximum value,so,we can say that this column contains outliers.
# 2.Similarly,for 'cost' column we can say that this column is also skewed and contains outliers.

# %%
# checking for outliers in 'votes' column
sns.boxplot(df['votes'])
print(df['votes'].skew())
# Out:
# 7.3912132212160415

# %%
# checking for outliers in 'cost' column
sns.boxplot(df['cost'])
print(df['cost'].skew())
# Out:
# 2.5825486058125673

# %%
# checking for outliers in 'rate' column
sns.boxplot(df['rate'])
print(df['rate'].skew())
# Out:
# -0.3545252165185422

# %%
df.describe(include='object').T
# Out:
#               count unique           top   freq
# online_order  48548      2           Yes  29107
# book_table    48548      2            No  42257
# location      48548     93           BTM   4692
# rest_type     48548     93   Quick Bites  17698
# cuisines      48548   2611  North Indian   2661
# service       48548      7      Delivery  24293
# city          48548     30           BTM   3057

# %%
# calculating interquartile range
q1=df.quantile(.25)
q3=df.quantile(.75)
iqr=q3-q1

# %%
iqr
# Out:
# rate       0.5
# votes    205.0
# cost     400.0
# dtype: float64

# %%
# treating outliers
df[((df < (q1-1.5*iqr)) | (df > (q3+1.5*iqr))).any(axis=1)]
# Out:
#       online_order book_table  rate  votes                    location  \
# 0              Yes        Yes   4.1    775                Banashankari
# 1              Yes         No   4.1    787                Banashankari
# 2              Yes         No   3.8    918                Banashankari
# 7              Yes        Yes   4.6   2556                Banashankari
# 14             Yes         No   3.8    918                Banashankari
# ...            ...        ...   ...    ...                         ...
# 51711           No         No   2.5     81                  Whitefield
# 51712           No         No   3.6     27                  Whitefield
# 51714           No         No   3.7      0                  Whitefield
# 51715           No        Yes   4.3    236  ITPL Main Road, Whitefield
# 51716           No         No   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  cost  \
# ...

# %%
# checking unique values of 'online_order' column
df['online_order'].value_counts()
# Out:
# Yes    29107
# No     19441
# Name: online_order, dtype: int64

# %%
# checking unique values of 'book_table' column
df['book_table'].value_counts()
# Out:
# No     42257
# Yes     6291
# Name: book_table, dtype: int64

# %% [markdown]
# Column 'book_table' is highly imbalanced.

# %%
# checking unique values of 'service' column
df['service'].value_counts()
# Out:
# Delivery              24293
# Dine-out              16658
# Desserts               3408
# Cafes                  1624
# Drinks & nightlife     1056
# Buffet                  851
# Pubs and bars           658
# Name: service, dtype: int64

# %%
# checking unique values of 'location' column
df['location'].value_counts()
# Out:
# BTM                      4692
# Koramangala 5th Block    2418
# HSR                      2376
# JP Nagar                 2078
# Whitefield               1961
#                          ...
# Yelahanka                   5
# West Bangalore              4
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: location, Length: 93, dtype: int64

# %%
# checking unique values of 'city' column
df['city'].unique()
# Out:
# array(['Banashankari', 'Bannerghatta Road', 'Basavanagudi', 'Bellandur',
#        'Brigade Road', 'Brookefield', 'BTM', 'Church Street',
#        'Electronic City', 'Frazer Town', 'HSR', 'Indiranagar',
#        'Jayanagar', 'JP Nagar', 'Kalyan Nagar', 'Kammanahalli',
#        'Koramangala 4th Block', 'Koramangala 5th Block',
#        'Koramangala 6th Block', 'Koramangala 7th Block', 'Lavelle Road',
#        'Malleshwaram', 'Marathahalli', 'MG Road', 'New BEL Road',
#        'Old Airport Road', 'Rajajinagar', 'Residency Road',
#        'Sarjapur Road', 'Whitefield'], dtype=object)

# %%
# checking count of unique values of 'rate' column
df.rate.value_counts()
# Out:
# 3.7    11164
# 3.9     3953
# 3.8     3816
# 3.6     3280
# 4.0     3142
# 4.1     2922
# 3.5     2761
# 3.4     2443
# 3.3     2272
# 4.2     2150
# 3.2     1838
# 4.3     1677
# 3.1     1550
# 4.4     1136
# 3.0      989
# 2.9      800
# 4.5      653
# 2.8      580
# 2.7      303
# 4.6      299
# 2.6      249
# 4.7      167
# 2.5      100
# 2.4       66
# 4.8       66
# 4.9       55
# 2.3       51
# 2.2       26
# 2.1       24
# 2.0       11
# 1.8        5
# Name: rate, dtype: int64

# %%
# plotting count of unique values of 'rate' column
figure=plt.figure(figsize=(15,5))
df['rate'].value_counts().plot(kind='bar')
plt.show()

# %%
# checking count of unique values of 'cost' column
df.cost.value_counts()
# Out:
# 300     6988
# 400     6210
# 500     4695
# 200     4426
# 600     3534
#         ...
# 70         1
# 469        1
# 5000       1
# 3700       1
# 360        1
# Name: cost, Length: 68, dtype: int64

# %%
# plotting count of unique values of 'cost' column 
figure=plt.figure(figsize=(15,5))
df['cost'].value_counts().plot(kind='bar')
plt.show()

# %%
# plotting count of unique values of 'online_order' column
df['online_order'].value_counts().plot(kind='bar')
plt.show()

# %%
# plotting count of unique values of 'book_table' column
df['book_table'].value_counts().plot(kind='bar')
plt.show()

# %%
# plotting count of unique values of 'location' column
figure=plt.figure(figsize=(18,5))
df['location'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# 'location' column has many unique values hence,we can say that there is a problem of cardinality here.

# %%
# plotting count of unique values of 'rest_type' column
figure=plt.figure(figsize=(18,5))
df['rest_type'].value_counts().plot(kind='bar')
plt.show()

# %%
# plotting count of unique values of 'service' column
df['service'].value_counts().plot(kind='bar')
plt.show()

# %%
# plotting count of unique values of 'city' column
df['city'].value_counts().plot(kind='bar')
plt.show()

# %%
# checking for the rows having value 0 in 'votes' column
df[df.votes == 0]
# Out:
#       online_order book_table  rate  votes      location           rest_type  \
# 84              No         No   3.7      0  Banashankari         Quick Bites
# 90              No         No   3.7      0  Banashankari            Delivery
# 91              No         No   3.7      0  Banashankari  Takeaway, Delivery
# 92              No         No   3.7      0  Banashankari                Mess
# 107             No         No   3.7      0  Banashankari  Takeaway, Delivery
# ...            ...        ...   ...    ...           ...                 ...
# 51644           No         No   3.7      0   Brookefield         Quick Bites
# 51675           No         No   3.7      0    Whitefield                 Bar
# 51710           No         No   3.7      0    Whitefield                 Bar
# 51713           No         No   3.7      0    Whitefield                 Bar
# 51714           No         No   3.7      0    Whitefield                 Bar
#
# ...

# %%
# checking for the rows having value 0 in 'rate' as well as 'votes' columns
df[(df.rate == 0) & (df.votes == 0)]
# Out:
# Empty DataFrame
# Columns: [online_order, book_table, rate, votes, location, rest_type, cuisines, cost, service, city]
# Index: []

# %%
# plotting boxplot of 'rate' column to check outliers
df.rate.plot(kind='box')
plt.show()

# %%
# checking skewness of 'rate' column
print("Skewness:", df.rate.skew())
sns.distplot(df.rate, hist=False)
plt.show()
# Out:
# Skewness: -0.3545252165185422

# %%
# checking skewness of 'votes' column
print("Skewness:", df.votes.skew())
sns.distplot(df['votes'], hist=False)
plt.show()
# Out:
# Skewness: 7.3912132212160415

# %%
# checking skewness of 'cost' column
print("Skewness:", df.cost.skew())
sns.distplot(df['cost'], hist=False)
plt.show()
# Out:
# Skewness: 2.5825486058125673

# %%
# plotting heatmap of numerical columns to check correlation between numerical columns
sns.heatmap(data=df.corr(),annot=True)
plt.show()

# %%
# plotting pairplot of numerical columns
sns.pairplot(data=df)
plt.show()

# %%
# ploting scatter plot between 'cost' and 'rate' columns with 'online_order' column
sns.scatterplot(x='cost', y='rate', hue='online_order', data=df)
# Out:
# <Axes: xlabel='cost', ylabel='rate'>

# %%
# ploting scatter plot between 'cost' and 'rate' columns with 'book_table' column
sns.scatterplot(x='cost', y='rate', hue='book_table', data=df)
# Out:
# <Axes: xlabel='cost', ylabel='rate'>

# %%
# ploting scatter plot between 'cost' and 'votes' columns with 'online_order' column
sns.scatterplot(x='cost', y='votes', hue='online_order', data=df)
# Out:
# <Axes: xlabel='cost', ylabel='votes'>

# %%
# ploting scatter plot between 'cost' and 'votes' columns with 'book_table' column
sns.scatterplot(x='cost', y='votes', hue='book_table', data=df)
# Out:
# <Axes: xlabel='cost', ylabel='votes'>

# %%
# ploting count plot of 'service' column with 'online_order' column
sns.countplot(x=df.service, hue=df.online_order)
plt.xticks(rotation=90)
plt.show()

# %%
# ploting count plot of 'service' column with 'book_table' column
sns.countplot(x=df.service, hue=df.book_table)
plt.xticks(rotation=90)
plt.show()

# %%
# ploting count plot of 'city' column with 'online_order' column
figure=plt.figure(figsize=(18,5))
sns.countplot(x=df.city, hue=df.online_order)
plt.xticks(rotation=90)
plt.show()

# %%
# ploting count plot of 'city' column with 'book_table' column
figure=plt.figure(figsize=(18,5))
sns.countplot(x=df.city, hue=df.book_table)
plt.xticks(rotation=90)
plt.show()

# %%
df1=df.copy()

# %%
# Encoding data

# %%
df1['online_order'] = df1['online_order'].replace({'Yes':1,'No':0})

# %%
df1['book_table'] = df1['book_table'].replace({'Yes':1,'No':0})

# %%
df1["location"] = df1.groupby("location")["cost"].transform("median")

# %%
df1["rest_type"] = df1.groupby("rest_type")["cost"].transform("median")

# %%
df1["cuisines"] = df1.groupby("cuisines")["cost"].transform("median")

# %%
df1['service'].value_counts()
# Out:
# Delivery              24293
# Dine-out              16658
# Desserts               3408
# Cafes                  1624
# Drinks & nightlife     1056
# Buffet                  851
# Pubs and bars           658
# Name: service, dtype: int64

# %%
df1['service'] = df1['service'].replace({'Delivery':0,'Dine-out':1,'Desserts':2,'Cafes':3,'Drinks & nightlife':4,'Buffet':5,'Pubs and bars':6})

# %%
areas = df1.city.value_counts().index.tolist()
obj = {}
for i in range(0,len(areas)):
  obj[areas[i]] = i
df1['city'] = df1['city'].replace(obj)

# %%
areas
# Out:
# ['BTM',
#  'Koramangala 7th Block',
#  'Koramangala 5th Block',
#  'Koramangala 4th Block',
#  'Koramangala 6th Block',
#  'Jayanagar',
#  'JP Nagar',
#  'MG Road',
#  'Church Street',
#  'Brigade Road',
#  'Indiranagar',
#  'Lavelle Road',
#  'HSR',
#  'Residency Road',
#  'Marathahalli',
#  'Whitefield',
#  'Bannerghatta Road',
#  'Brookefield',
#  'Old Airport Road',
#  'Kammanahalli',
#  'Kalyan Nagar',
#  'Sarjapur Road',
#  'Basavanagudi',
#  'Frazer Town',
#  'Bellandur',
#  'Electronic City',
#  'Malleshwaram',
#  'Rajajinagar',
#  'Banashankari',
#  'New BEL Road']

# %%
#Here,we have first made a list of all the values of a 'city' column and then replaced those city names with their respective counts.

# %%
df1.head()
# Out:
#    online_order  book_table  rate  votes  location  rest_type  cuisines  cost  \
# 0             1           1   4.1    775     350.0      700.0     500.0   800
# 1             1           0   4.1    787     350.0      700.0     850.0   800
# 2             1           0   3.8    918     350.0      800.0     800.0   800
# 3             0           0   3.7     88     350.0      300.0     300.0   300
# 4             0           0   3.8    166     300.0      700.0     500.0   600
#
#    service  city
# 0        5    28
# 1        5    28
# 2        5    28
# 3        5    28
# 4        5    28

# %% [markdown]
# Now,our entire dataset is containing all numerical columns.

# %%
sns.heatmap(df1.select_dtypes('number').corr(),annot=True)
# Out:
# <Axes: >

# %%
for i in df1:
  print(i)
  sns.distplot(df1[i])
  plt.show()
# Out:
# online_order
# book_table
# rate
# votes
# location
# rest_type
# cuisines
# cost
# service
# city

# %%
df1.skew()
# Out:
# online_order   -0.406352
# book_table      2.205954
# rate           -0.354525
# votes           7.391213
# location        3.297909
# rest_type       3.084826
# cuisines        2.704459
# cost            2.582549
# service         2.170432
# city            0.390121
# dtype: float64

# %%
#scaling the data

# %%
df1 = df1.apply(lambda rec: (rec - rec.mean()) / rec.std())    #usig z-score formula 

df1.head()
# Out:
#    online_order  book_table      rate     votes  location  rest_type  \
# 0      0.817252    2.591702  0.983507  0.577733 -0.697330   0.477393
# 1      0.817252   -0.385839  0.983507  0.592301 -0.697330   0.477393
# 2      0.817252   -0.385839  0.243124  0.751336 -0.697330   0.753309
# 3     -1.223587   -0.385839 -0.003670 -0.256287 -0.697330  -0.626269
# 4     -1.223587   -0.385839  0.243124 -0.161595 -1.002963   0.477393
#
#    cuisines      cost   service      city
# 0 -0.091975  0.533224  3.403736  1.943975
# 1  0.805259  0.533224  3.403736  1.943975
# 2  0.677083  0.533224  3.403736  1.943975
# 3 -0.604681 -0.591593  3.403736  1.943975
# 4 -0.091975  0.083297  3.403736  1.943975

# %%
df1['votes'] = np.cbrt(df1['votes'])

# %%
df1['votes'].skew()
# Out:
# 1.7629700320755646

# %%
df1['location'] = np.cbrt(df1['location'])

# %%
df1.skew()
# Out:
# online_order   -0.406352
# book_table      2.205954
# rate           -0.354525
# votes           1.762970
# location        0.800370
# rest_type       3.084826
# cuisines        2.704459
# cost            2.582549
# service         2.170432
# city            0.390121
# dtype: float64

# %% [markdown]
# # Model Building

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# #Train Test Split for all the models

# %%
# create dataframe of features by dropping the target variable
# 'axis = 1' drops the corresponding column(s)
df1_feature = df1.drop('cost', axis = 1)

# create dataframe of target variable
df1_target = df1['cost']

# %%
#we are calculating vif factor to check the multicollinearity among independent numerical variables.
df1_vif = df1_feature.select_dtypes(include=[np.number])


df1_vif.head()
# Out:
#    online_order  book_table      rate     votes  location  rest_type  \
# 0      0.817252    2.591702  0.983507  0.832867 -0.886774   0.477393
# 1      0.817252   -0.385839  0.983507  0.839810 -0.886774   0.477393
# 2      0.817252   -0.385839  0.243124  0.909099 -0.886774   0.753309
# 3     -1.223587   -0.385839 -0.003670 -0.635197 -0.886774  -0.626269
# 4     -1.223587   -0.385839  0.243124 -0.544681 -1.000987   0.477393
#
#    cuisines   service      city
# 0 -0.091975  3.403736  1.943975
# 1  0.805259  3.403736  1.943975
# 2  0.677083  3.403736  1.943975
# 3 -0.604681  3.403736  1.943975
# 4 -0.091975  3.403736  1.943975

# %%
df1_vif.isna().sum()
# Out:
# online_order    0
# book_table      0
# rate            0
# votes           0
# location        0
# rest_type       0
# cuisines        0
# service         0
# city            0
# dtype: int64

# %%
np.isinf(df1_vif).sum()
# Out:
# online_order    0
# book_table      0
# rate            0
# votes           0
# location        0
# rest_type       0
# cuisines        0
# service         0
# city            0
# dtype: int64

# %%
import statsmodels
from statsmodels.stats.outliers_influence import variance_inflation_factor
# create an empty dataframe to store the VIF for each variable
vif = pd.DataFrame()

# calculate VIF using list comprehension 
# use for loop to access each variable 
# calculate VIF for each variable and create a column 'VIF_Factor' to store the values 
vif["VIF_Factor"] = [variance_inflation_factor(df1_vif.values, i) for i in range(df1_vif.shape[1])]

# create a column of variable names
vif["Features"] = df1_vif.columns

# sort the dataframe based on the values of VIF_Factor in descending order
# 'ascending = False' sorts the data in descending order
# 'reset_index' resets the index of the dataframe
# 'drop = True' drops the previous index
vif.sort_values('VIF_Factor', ascending = False).reset_index(drop = True)
# Out:
#    VIF_Factor      Features
# 0    2.359379      cuisines
# 1    2.335781     rest_type
# 2    1.776150    book_table
# 3    1.645091         votes
# 4    1.421968          rate
# 5    1.266662       service
# 6    1.251675      location
# 7    1.106285  online_order
# 8    1.040704          city

# %% [markdown]
# The output shows that VIF of all variables is less than 10(we set 10 as threshold).So,we can conclude that there is no multicollinearity in the data.

# %%
# set of independent variables
# create a copy of 'df1_compensation_dummy' and store in the dataframe 'X_full'
X_full = df1_feature.copy()

# dependent variable
# create a copy of 'df1_target' and store in the dataframe 'y_full'
y_full = df1_target.copy()

# to estimate the regression coefficient, a constant term of '1' needs to be added as a separate column
# 'sm.add_constant' adds the intercept to the model
X_full = sm.add_constant(X_full)

# split data into train subset and test subset
# set 'random_state' to generate the same dataset each time you run the code 
# 'test_size' returns the proportion of data to be included in the testing set
X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(X_full, y_full, random_state=1, test_size = 0.3)

# checking the dimensions of the train & test subset
# print dimension of train set
print('X_train_full', X_train_full.shape)
print('y_train_full', y_train_full.shape)

# print dimension of test set
print('X_test_full', X_test_full.shape)
print('y_test_full', y_test_full.shape)
# Out:
# X_train_full (33983, 10)
# y_train_full (33983,)
# X_test_full (14565, 10)
# y_test_full (14565,)

# %%
# build a model on training dataset
# fit() is used to fit the OLS model
MLR_full_model = sm.OLS(y_train_full, X_train_full).fit()

# print the summary output
print(MLR_full_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   cost   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                 1.826e+04
# Date:                Sat, 13 May 2023   Prob (F-statistic):               0.00
# Time:                        17:29:38   Log-Likelihood:                -18024.
# No. Observations:               33983   AIC:                         3.607e+04
# Df Residuals:                   33973   BIC:                         3.615e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0222      0.003      7.902      0.000       0.017       0.028
# ...

# %%
#check Prob(F-statistic)
#H0: none of the features are useful/significant while making the prediction
#H1: atleast one of the features is useful while making the prediction

#As Prob(F-statistic)<0.05,we reject null hypothesis.
#Hence,we infer that,atleast one of the features is useful/significant while making the prediction.

# %%
#p|t|: pval>0.05 it would indicate that that feature is probably junk
#H0:Feature is not contributing towards the prediction
#H1:Feature is contributing towards the prediction
#As pval<0.05 for all the independent variables,we reject null hypothesis.
#So,these features are impacting cost.

# %%
#multicollinearity through Cond.no.
#As Cond.no.<100,we can say that data has no multicollinearity.

# %%
#checking for normality
#H0:data is normal and kurtosis is mesokurtic
#H1:data is not normal and kurtosis is not mesokurtic
#As Prob(JB)<0.05,we can say that,data is not normal and kurtosis is not mesokurtic.
#As kurtosis=+ive,we can say that data is leptokurtic.

# %%
#for autocorrelation,check Durbin-Watson
#As it is close to 2,there is no autocorrelation.

# %% [markdown]
# Tests for Normality

# %%
#QQ-Plot
# set the plot size using 'rcParams'
# once the plot size is set using 'rcParams', it sets the size of all the forthcoming plots in the file
# pass width and height in inches to 'figure.figsize' 


plt.rcParams['figure.figsize'] = [10,8]

# plot the Q-Q plot
# 'r' represents the regression line

from statsmodels.graphics.gofplots import qqplot
qqplot(MLR_full_model.resid, line = 'r')



# set plot and axes labels
# set text size using 'fontsize'
plt.title('Q-Q Plot', fontsize = 15)
plt.xlabel('Theoretical Quantiles', fontsize = 15)
plt.ylabel('Sample Quantiles', fontsize = 15)

# display the plot
plt.show()

# %% [markdown]
# The diagonal line (red line) is the regression line and the blue points are the cumulative distribution of the residuals. As some of the points are close to the diagonal line, we conclude that the residuals do not follow a normal distribution.

# %%
#shapiro-wilk test
#Ho: Residuals are normally distributed
#H1: Residuals are not normally distributed
from scipy.stats import shapiro
stat, p_value = shapiro(MLR_full_model.resid)

print('Test statistic:', stat)
print('P-Value:', p_value)
# Out:
# Test statistic: 0.8351373672485352
# P-Value: 0.0

# %% [markdown]
# As p-val<0.05,we can say that residuals are not normally distributed.

# %% [markdown]
# # Model Performance

# %%
train_pred = MLR_full_model.predict(X_train_full)

# predict the output of the target variable from the test data
test_pred = MLR_full_model.predict(X_test_full)

# %%
reg_mse_train = mean_squared_error(y_train_full, train_pred)
reg_rmse_train = round(np.sqrt(reg_mse_train),2)
reg_r2_score_train = round(r2_score(y_train_full, train_pred)*100,2)
print('MLR model MSE value for train: ',reg_mse_train)
print('MLR model RMSE value for train: ',reg_rmse_train)
print('MLR model R2 score for train is:',reg_r2_score_train)
print('-------------------------------------------------------------------------')
reg_mse_test = mean_squared_error(y_test_full, test_pred)
reg_rmse_test = round(np.sqrt(reg_mse_test),2)
reg_r2_score_test = round(r2_score(y_test_full,test_pred)*100,2)
print('MLR model MSE value for test: ',reg_mse_test)
print('MLR model RMSE value for test: ',reg_rmse_test)
print('MLR model R2 score for test is:',reg_r2_score_test)
# Out:
# MLR model MSE value for train:  0.16912705139125167
# MLR model RMSE value for train:  0.41
# MLR model R2 score for train is: 82.87
# -------------------------------------------------------------------------
# MLR model MSE value for test:  0.16781605594920335
# MLR model RMSE value for test:  0.41
# MLR model R2 score for test is: 83.7

# %%
#Mean Squared Error
mse_train = round(mean_squared_error(y_train_full, train_pred),4)

print("Mean Squared Error (MSE) on training set: ", mse_train)

mse_test = round(mean_squared_error(y_test_full, test_pred),4)

print("Mean Squared Error (MSE) on test set: ", mse_test)
# Out:
# Mean Squared Error (MSE) on training set:  0.1691
# Mean Squared Error (MSE) on test set:  0.1678

# %%
#RMSE-lesser the RMSE better the model
rmse_train = round(np.sqrt(mse_train), 4)
print("Root Mean Squared Error (RMSE) on training set: ", rmse_train)

rmse_test = round(np.sqrt(mse_test), 4)
print("Root Mean Squared Error (RMSE) on test set: ", rmse_test)
# Out:
# Root Mean Squared Error (RMSE) on training set:  0.4112
# Root Mean Squared Error (RMSE) on test set:  0.4096

# %% [markdown]
# #Support Vector Machine

# %%
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
svc_model = SVR(C=0.1, kernel='linear', gamma=1)
svc_model.fit(X_train_full, y_train_full)
# Out:
# SVR(C=0.1, gamma=1, kernel='linear')

# %%
svc_train_pred = svc_model.predict(X_train_full)
svc_test_pred = svc_model.predict(X_test_full)

svc_mse_train = mean_squared_error(y_train_full, svc_train_pred)
svc_rmse_train = round(np.sqrt(svc_mse_train),2)
svc_r2_score_train = round(r2_score(y_train_full, svc_train_pred)*100,2)
print('SVC model MSE value for train: ',svc_mse_train)
print('SVC model RMSE value for train: ',svc_rmse_train)
print('SVC model R2 score for train is:',svc_r2_score_train)
print('-------------------------------------------------------------------------')
svc_mse_test = mean_squared_error(y_test_full, svc_test_pred)
svc_rmse_test = round(np.sqrt(svc_mse_test),2)
svc_r2_score_test = round(r2_score(y_test_full,svc_test_pred)*100,2)
print('SVC model MSE value for test: ',svc_mse_test)
print('SVC model RMSE value for test: ',svc_rmse_test)
print('SVC model R2 score for test is:',svc_r2_score_test)
# Out:
# SVC model MSE value for train:  0.1934182996348988
# SVC model RMSE value for train:  0.44
# SVC model R2 score for train is: 80.41
# -------------------------------------------------------------------------
# SVC model MSE value for test:  0.19349571169984145
# SVC model RMSE value for test:  0.44
# SVC model R2 score for test is: 81.21

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# %%
decision_tree = DecisionTreeRegressor(max_depth=3)
decision_tree.fit(X_train_full, y_train_full)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
dt_train_pred = decision_tree.predict(X_train_full)
dt_test_pred = decision_tree.predict(X_test_full)

dt_mse_train = mean_squared_error(y_train_full, dt_train_pred)
dt_rmse_train = round(np.sqrt(dt_mse_train),2)
dt_r2_score_train = round(r2_score(y_train_full, dt_train_pred)*100,2)
print('DT model MSE value for train: ',dt_mse_train)
print('DT model RMSE value for train: ',dt_rmse_train)
print('DT model R2 score for train is:',dt_r2_score_train)
print('-------------------------------------------------------------------------')
dt_mse_test = mean_squared_error(y_test_full, dt_test_pred)
dt_rmse_test = round(np.sqrt(dt_mse_test),2)
dt_r2_score_test = round(r2_score(y_test_full,dt_test_pred)*100,2)
print('DT model MSE value for test: ',dt_mse_test)
print('DT model RMSE value for test: ',dt_rmse_test)
print('DT model R2 score for test is:',dt_r2_score_test)
# Out:
# DT model MSE value for train:  0.22837898468289022
# DT model RMSE value for train:  0.48
# DT model R2 score for train is: 76.87
# -------------------------------------------------------------------------
# DT model MSE value for test:  0.22832137065083824
# DT model RMSE value for test:  0.48
# DT model R2 score for test is: 77.83

# %%
tree.plot_tree(decision_tree)
# Out:
# [Text(0.5, 0.875, 'x[7] <= 1.158\nsquared_error = 0.987\nsamples = 33983\nvalue = -0.002'),
#  Text(0.25, 0.625, 'x[6] <= 0.064\nsquared_error = 0.399\nsamples = 30097\nvalue = -0.247'),
#  Text(0.125, 0.375, 'x[7] <= -0.509\nsquared_error = 0.1\nsamples = 20838\nvalue = -0.51'),
#  Text(0.0625, 0.125, 'squared_error = 0.065\nsamples = 10931\nvalue = -0.654'),
#  Text(0.1875, 0.125, 'squared_error = 0.091\nsamples = 9907\nvalue = -0.352'),
#  Text(0.375, 0.375, 'x[6] <= 2.547\nsquared_error = 0.567\nsamples = 9259\nvalue = 0.344'),
#  Text(0.3125, 0.125, 'squared_error = 0.328\nsamples = 9126\nvalue = 0.293'),
#  Text(0.4375, 0.125, 'squared_error = 4.282\nsamples = 133\nvalue = 3.879'),
#  Text(0.75, 0.625, 'x[7] <= 3.433\nsquared_error = 1.47\nsamples = 3886\nvalue = 1.896'),
#  Text(0.625, 0.375, 'x[7] <= 2.023\nsquared_error = 0.82\nsamples = 3485\nvalue = 1.648'),
#  Text(0.5625, 0.125, 'squared_error = 0.528\nsamples = 2012\nvalue = 1.274'),
# ...

# %% [markdown]
# #Random Forest Extra trees Regressor

# %%
model = ExtraTreesRegressor()
model.fit(df1_feature,df1_target)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.0115287  0.31785808 0.02971123 0.03123178 0.02653628 0.29692177
#  0.26273293 0.01092016 0.01255908]

# %%
feat_importances = pd.Series(model.feature_importances_, index=df1_feature.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.title('Feature Importances')
plt.show()

# %%
feat_importances.sort_values()
# Out:
# service         0.010920
# online_order    0.011529
# city            0.012559
# location        0.026536
# rate            0.029711
# votes           0.031232
# cuisines        0.262733
# rest_type       0.296922
# book_table      0.317858
# dtype: float64

# %%
regressor=RandomForestRegressor()

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
max_features = ['auto', 'sqrt'] 
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train_full,y_train_full)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  16.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  16.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  15.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  16.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=  16.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  26.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=  28.1s
# ...

# %%
rfet_train_pred = rf_random.predict(X_train_full)
rfet_test_pred = rf_random.predict(X_test_full)

rfet_mse_train = mean_squared_error(y_train_full, rfet_train_pred)
rfet_rmse_train = round(np.sqrt(rfet_mse_train),2)
rfet_r2_score_train = round(r2_score(y_train_full, rfet_train_pred)*100,2)
print('RFET model MSE value for train: ',rfet_mse_train)
print('RFET model RMSE value for train: ',rfet_rmse_train)
print('RFET model R2 score for train is:',rfet_r2_score_train)
print('-------------------------------------------------------------------------')
rfet_mse_test = mean_squared_error(y_test_full, rfet_test_pred)
rfet_rmse_test = round(np.sqrt(rfet_mse_test),2)
rfet_r2_score_test = round(r2_score(y_test_full,rfet_test_pred)*100,2)
print('RFET model MSE value for test: ',rfet_mse_test)
print('RFET model RMSE value for test: ',rfet_rmse_test)
print('RFET model R2 score for test is:',rfet_r2_score_test)
# Out:
# RFET model MSE value for train:  0.008220129979937334
# RFET model RMSE value for train:  0.09
# RFET model R2 score for train is: 99.17
# -------------------------------------------------------------------------
# RFET model MSE value for test:  0.03676365252516271
# RFET model RMSE value for test:  0.19
# RFET model R2 score for test is: 96.43

# %%
df1_check = pd.DataFrame({'Actual': y_test_full, 'Predicted': rfet_test_pred})
df1_check = df1_check.head(25)
df1_check.plot(kind='bar',figsize=(10,5))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.title('Performance of Random Forest')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# #KNN Regressor

# %%
st_x = StandardScaler()    
x_train = st_x.fit_transform(X_train_full)    
x_test = st_x.transform(X_test_full)

# %%
knnregressor= KNeighborsRegressor(n_neighbors=5, metric='minkowski', p=2)  
knnregressor.fit(x_train, y_train_full)
# Out:
# KNeighborsRegressor()

# %%
knn_train_pred = knnregressor.predict(x_train)
knn_test_pred = knnregressor.predict(x_test)

knn_mse_train = mean_squared_error(y_train_full, knn_train_pred)
knn_rmse_train = round(np.sqrt(knn_mse_train),2)
knn_r2_score_train = round(r2_score(y_train_full, knn_train_pred)*100,2)
print('KNN model MSE value for train: ',knn_mse_train)
print('KNN model RMSE value for train: ',knn_rmse_train)
print('KNN model R2 score for train is:',knn_r2_score_train)
print('-------------------------------------------------------------------------')
knn_mse_test = mean_squared_error(y_test_full, knn_test_pred)
knn_rmse_test = round(np.sqrt(knn_mse_test),2)
knn_r2_score_test = round(r2_score(y_test_full,knn_test_pred)*100,2)
print('KNN model MSE value for test: ',knn_mse_test)
print('KNN model RMSE value for test: ',knn_rmse_test)
print('KNN model R2 score for test is:',knn_r2_score_test)
# Out:
# KNN model MSE value for train:  0.06422286894758683
# KNN model RMSE value for train:  0.25
# KNN model R2 score for train is: 93.49
# -------------------------------------------------------------------------
# KNN model MSE value for test:  0.1071342138621982
# KNN model RMSE value for test:  0.33
# KNN model R2 score for test is: 89.6

# %% [markdown]
# #Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(loss='absolute_error', learning_rate=0.1, n_estimators=300, max_depth = 1, random_state = 10, max_features = 5)

# %%
gbr.fit(X_train_full, y_train_full)

# %%
gbr_train_pred = gbr.predict(X_train_full)
gbr_test_pred = gbr.predict(X_test_full)

gbr_mse_train = mean_squared_error(y_train_full, gbr_train_pred)
gbr_rmse_train = round(np.sqrt(gbr_mse_train),2)
gbr_r2_score_train = round(r2_score(y_train_full, gbr_train_pred)*100,2)
print('GBR model MSE value for train: ',gbr_mse_train)
print('GBR model RMSE value for train: ',gbr_rmse_train)
print('GBR model R2 score for train is:',gbr_r2_score_train)
print('-------------------------------------------------------------------------')
gbr_mse_test = mean_squared_error(y_test_full, gbr_test_pred)
gbr_rmse_test = round(np.sqrt(gbr_mse_test),2)
gbr_r2_score_test = round(r2_score(y_test_full,gbr_test_pred)*100,2)
print('GBR model MSE value for test: ',gbr_mse_test)
print('GBR model RMSE value for test: ',gbr_rmse_test)
print('GBR model R2 score for test is:',gbr_r2_score_test)

# %% [markdown]
# #Xtreme Gradient Boosting

# %%
import xgboost as xg

# %%
xgb_r = xg.XGBRegressor(objective ='reg:linear', n_estimators = 10, seed = 123)

# %%
xgb_r.fit(X_train_full, y_train_full)

# %%
xgbr_train_pred = xgb_r.predict(X_train_full)
xgbr_test_pred = xgb_r.predict(X_test_full)

xgbr_mse_train = mean_squared_error(y_train_full, xgbr_train_pred)
xgbr_rmse_train = round(np.sqrt(xgbr_mse_train),2)
xgbr_r2_score_train = round(r2_score(y_train_full, xgbr_train_pred)*100,2)
print('XGBR model MSE value for train: ',xgbr_mse_train)
print('XGBR model RMSE value for train: ',xgbr_rmse_train)
print('XGBR model R2 score for train is:',xgbr_r2_score_train)
print('-------------------------------------------------------------------------')
xgbr_mse_test = mean_squared_error(y_test_full, xgbr_test_pred)
xgbr_rmse_test = round(np.sqrt(xgbr_mse_test),2)
xgbr_r2_score_test = round(r2_score(y_test_full,xgbr_test_pred)*100,2)
print('XGBR model MSE value for test: ',xgbr_mse_test)
print('XGBR model RMSE value for test: ',xgbr_rmse_test)
print('XGBR model R2 score for test is:',xgbr_r2_score_test)

# %% [markdown]
# #Ada Boosting

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import GridSearchCV

# %%
ada_reg=AdaBoostRegressor(n_estimators=100, random_state=10).fit(X_train_full, y_train_full)

# %%
scores = cross_val_score(ada_reg, X_train_full,y_train_full,cv=5)
print("Mean cross-validataion score: %.2f" % scores.mean())

# %%
kfold = KFold(n_splits=10, shuffle=True)
kf_cv_scores = cross_val_score(ada_reg, X_train_full, y_train_full, cv=kfold )
print("K-fold CV average score: %.2f" % kf_cv_scores.mean())

# %%
adab_train_pred = ada_reg.predict(X_train_full)
adab_test_pred = ada_reg.predict(X_test_full)

adab_mse_train = mean_squared_error(y_train_full, adab_train_pred)
adab_rmse_train = round(np.sqrt(adab_mse_train),2)
adab_r2_score_train = round(r2_score(y_train_full, adab_train_pred)*100,2)
print('AdaB model MSE value for train: ',adab_mse_train)
print('AdaB model RMSE value for train: ',adab_rmse_train)
print('AdaB model R2 score for train is:',adab_r2_score_train)
print('-------------------------------------------------------------------------')
adab_mse_test = mean_squared_error(y_test_full, adab_test_pred)
adab_rmse_test = round(np.sqrt(adab_mse_test),2)
adab_r2_score_test = round(r2_score(y_test_full,adab_test_pred)*100,2)
print('AdaB model MSE value for test: ',adab_mse_test)
print('AdaB model RMSE value for test: ',adab_rmse_test)
print('AdaB model R2 score for test is:',adab_r2_score_test)

# %%
ypred = ada_reg.predict(X_test_full)
mse = mean_squared_error(y_test_full,ypred)
print("MSE: %.2f" % mse)
print("RMSE: %.2f" % np.sqrt(mse))

# %%
x_ax = range(len(y_test_full))
plt.scatter(x_ax, y_test_full, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %% [markdown]
# #Pivot Table for all models RMSE and r2 score

# %%
df11=pd.DataFrame({'Model': ['Linear regression', 'Support Vector Machine','Decision Tree Regressor', 'Random Forest Extra Trees Regressor', 'KNN regressor', 'Gradient Boosting Regressor', 'Xtreme Gradient Boosting',
                                 'Ada Boosting regressor'],
                'RMSE Train Value': [reg_rmse_train, svc_rmse_train, dt_rmse_train, rfet_rmse_train, knn_rmse_train, gbr_rmse_train,xgbr_rmse_train,adab_rmse_train],
                'RMSE Test Value': [reg_rmse_test, svc_rmse_test, dt_rmse_test, rfet_rmse_test, knn_rmse_test, gbr_rmse_test,xgbr_rmse_test,adab_rmse_test],
                'R2 SCORE Train': [reg_r2_score_train, svc_r2_score_train, dt_r2_score_train, rfet_r2_score_train, knn_r2_score_train, gbr_r2_score_train,xgbr_r2_score_train,adab_r2_score_train],
                'R2 SCORE Test': [reg_r2_score_test, svc_r2_score_test, dt_r2_score_test, rfet_r2_score_test, knn_r2_score_test, gbr_r2_score_test,xgbr_r2_score_test,adab_r2_score_test]})

# %%
table=pd.pivot_table(df11, index=['Model', 'RMSE Train Value','RMSE Test Value','R2 SCORE Train','R2 SCORE Test'])
table

# %% [markdown]
# # **Section B**

# %% [markdown]
# ## **Title: Classification**
#
# ### **Problem Statement:**
#
# The model that you built in the above case study has gone to deployment and Zomato has been impressed with your data analysis and Zomoto has been believing that your analysis going to be impactful. Now Zomato has been observing the orders happening online and offline, Due to offline orders, Zomato is not able to attract customers with diverse items and offers, and the user subscription also getting low. so it has decided to give you the project on the same. Now the problem statement is that Zomato wants to know whether the customer would order the orders online or offline so that Zomato can take further strategies to improve the online order.
#
# ### **Objective:**
#
# The Aim is to classify the orders that have been ordered online and offline. And identify the patterns that lead to orders online orders as well as offline. Your model should be able to classify the classes effectively.
#
# ### **Steps that are to be followed:**
#
# **Step 1:** Understand the problem statement, Identify the metric for the problem.
#
# **Step 2:** Use the data sets that have been cleaned data types and missing values in **Section A Step 3**.
#
# **Step 3:**
#
# **i)** Explore the data and find the hidden patterns in the data that affect your objective(target variable).
#
# **ii)** Find the features that would impact the target variable.
#
# **Step 4:** Do the preprocessing in a way that impacts the models that you going to build.
#
#     Note: If you feel the few preprocessing steps that you did in Section A, feel free to use those steps.
#
# **Step 5:** Prove statistically about step 2 point ii.
#
# **Step 6:** Split the data into train and test sets.
#
# **Step 7:** Build the base model and Identify your metric based on the problem.
#
# **Step 8:** Try to improve your metric by trying different models, changing the feature engineering methods, feature selection, etc.
#
# **Step 9:** Choose the final model and tune the model.
#
# **Step 10:** Write your business interpretation. And explain the reasons behind choosing the final model and how the chosen model performs well compared to other models.

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
df.head()
# Out:
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3           No         No   3.7     88  Banashankari          Quick Bites
# 4           No         No   3.8    166  Basavanagudi        Casual Dining
#
#                          cuisines  cost service          city
# 0  North Indian, Mughlai, Chinese   800  Buffet  Banashankari
# 1     Chinese, North Indian, Thai   800  Buffet  Banashankari
# 2          Cafe, Mexican, Italian   800  Buffet  Banashankari
# 3      South Indian, North Indian   300  Buffet  Banashankari
# 4        North Indian, Rajasthani   600  Buffet  Banashankari

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
# 3           No         No   3.7     88  Banashankari          Quick Bites
# 4           No         No   3.8    166  Basavanagudi        Casual Dining
#
#                          cuisines  cost service          city
# 0  North Indian, Mughlai, Chinese   800  Buffet  Banashankari
# 1     Chinese, North Indian, Thai   800  Buffet  Banashankari
# 2          Cafe, Mexican, Italian   800  Buffet  Banashankari
# 3      South Indian, North Indian   300  Buffet  Banashankari
# 4        North Indian, Rajasthani   600  Buffet  Banashankari

# %% [markdown]
# Encoding the data

# %%
df2['online_order'] = df2['online_order'].replace({'Yes':1,'No':0})

# %%
df2['book_table'] = df2['book_table'].replace({'Yes':1,'No':0})

# %%
df2["location"] = df2.groupby("location")["cost"].transform("median")

# %%
df2["rest_type"] = df2.groupby("rest_type")["cost"].transform("median")

# %%
df2["cuisines"] = df2.groupby("cuisines")["cost"].transform("median")

# %%
df2['service'].value_counts()
# Out:
# Delivery              24293
# Dine-out              16658
# Desserts               3408
# Cafes                  1624
# Drinks & nightlife     1056
# Buffet                  851
# Pubs and bars           658
# Name: service, dtype: int64

# %%
df2['service'] = df2['service'].replace({'Delivery':0,'Dine-out':1,'Desserts':2,'Cafes':3,'Drinks & nightlife':4,'Buffet':5,'Pubs and bars':6})

# %%
areas = df2.city.value_counts().index.tolist()
obj = {}
for i in range(0,len(areas)):
  obj[areas[i]] = i
df2['city'] = df2['city'].replace(obj)

# %%
df2.head()
# Out:
#    online_order  book_table  rate  votes  location  rest_type  cuisines  cost  \
# 0             1           1   4.1    775     350.0      700.0     500.0   800
# 1             1           0   4.1    787     350.0      700.0     850.0   800
# 2             1           0   3.8    918     350.0      800.0     800.0   800
# 3             0           0   3.7     88     350.0      300.0     300.0   300
# 4             0           0   3.8    166     300.0      700.0     500.0   600
#
#    service  city
# 0        5    28
# 1        5    28
# 2        5    28
# 3        5    28
# 4        5    28

# %% [markdown]
# Split the dependent and independent variables.

# %%
# create dataframe of features by dropping the target variable
# 'axis = 1' drops the corresponding column(s)
x = df2.drop('online_order', axis = 1)

# create dataframe of target variable
y = df2['online_order']

# %% [markdown]
# Normalize the data

# %%
# initialize the MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler()

# normalize all the numerical columns
# normalize all the columns of the dataframe 'df1_feature'
num_norm = X_norm.fit_transform(x)

# create a dataframe of scaled numerical variables
# pass the required column names to the parameter 'columns'
X = pd.DataFrame(num_norm, columns = x.columns)

X.head()
# Out:
#    book_table      rate     votes  location  rest_type  cuisines      cost  \
# 0         1.0  0.741935  0.046043  0.046512   0.181818  0.067797  0.127517
# 1         0.0  0.741935  0.046756  0.046512   0.181818  0.127119  0.127517
# 2         0.0  0.645161  0.054539  0.046512   0.212121  0.118644  0.127517
# 3         0.0  0.612903  0.005228  0.046512   0.060606  0.033898  0.043624
# 4         0.0  0.645161  0.009862  0.023256   0.181818  0.067797  0.093960
#
#     service      city
# 0  0.833333  0.965517
# 1  0.833333  0.965517
# 2  0.833333  0.965517
# 3  0.833333  0.965517
# 4  0.833333  0.965517

# %%
# create a generalized function to calculate the performance metrics values for test set
def get_test_report(model, test_data):
    
    # for test set:
    # test_pred: prediction made by the model on the test dataset 'X_test'
    # y_test: actual values of the target variable for the test dataset

    # predict the output of the target variable from the test data 
    test_pred = model.predict(test_data)

    # return the classification report for test data
    return(classification_report(y_test, test_pred))

# %%
# define a function  to plot a confusion matrix for the model
def plot_confusion_matrix(model, test_data):
    
    # predict the target values using X_test
    y_pred = model.predict(test_data)
    
    # create a confusion matrix
    # pass the actual and predicted target values to the confusion_matrix()
    cm = confusion_matrix(y_test, y_pred)

    # label the confusion matrix  
    # pass the matrix as 'data'
    # pass the required column names to the parameter, 'columns'
    # pass the required row names to the parameter, 'index'
    conf_matrix = pd.DataFrame(data = cm,columns = ['Predicted:0','Predicted:1'], index = ['Actual:0','Actual:1'])

    # plot a heatmap to visualize the confusion matrix
    # 'annot' prints the value of each grid 
    # 'fmt = d' returns the integer value in each grid
    # 'cmap' assigns color to each grid
    # as we do not require different colors for each grid in the heatmap,
    # use 'ListedColormap' to assign the specified color to the grid
    # 'cbar = False' will not return the color bar to the right side of the heatmap
    # 'linewidths' assigns the width to the line that divides each grid
    # 'annot_kws = {'size':25})' assigns the font size of the annotated text 
    sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = ListedColormap(['lightskyblue']), cbar = False, 
                linewidths = 0.1, annot_kws = {'size':25})

    # set the font size of x-axis ticks using 'fontsize'
    plt.xticks(fontsize = 20)

    # set the font size of y-axis ticks using 'fontsize'
    plt.yticks(fontsize = 20)

    # display the plot
    plt.show()

# %%
# define a function to plot the ROC curve and print the ROC-AUC score
def plot_roc(model, test_data):
    
    # predict the probability of target variable using X_test
    # consider the probability of positive class by subsetting with '[:,1]'
    y_pred_prob = model.predict_proba(test_data)[:,1]
    
    # the roc_curve() returns the values for false positive rate, true positive rate and threshold
    # pass the actual target values and predicted probabilities to the function
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

    # plot the ROC curve
    plt.plot(fpr, tpr)

    # set limits for x and y axes
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])

    # plot the straight line showing worst prediction for the model
    plt.plot([0, 1], [0, 1],'r--')

    # add plot and axes labels
    # set text size using 'fontsize'
    plt.title('ROC curve for Online order  Classifier', fontsize = 15)
    plt.xlabel('False positive rate (1-Specificity)', fontsize = 15)
    plt.ylabel('True positive rate (Sensitivity)', fontsize = 15)

    # add the AUC score to the plot
    # 'x' and 'y' gives position of the text
    # 's' is the text 
    # use round() to round-off the AUC score upto 4 digits
    plt.text(x = 0.02, y = 0.9, s = ('AUC Score:',round(roc_auc_score(y_test, y_pred_prob),4)))

    # plot the grid
    plt.grid(True)

# %%
# split data into train subset and test subset
# set 'random_state' to generate the same dataset each time you run the code 
# 'test_size' returns the proportion of data to be included in the testing set
X_train_norm, X_test_norm, y_train, y_test = train_test_split(X, y, random_state = 10, test_size = 0.3)

# check the dimensions of the train & test subset using 'shape'
# print dimension of train set
print('X_train_norm', X_train_norm.shape)
print('y_train', y_train.shape)

# print dimension of test set
print('X_test_norm', X_test_norm.shape)
print('y_test', y_test.shape)
# Out:
# X_train_norm (33983, 9)
# y_train (33983,)
# X_test_norm (14565, 9)
# y_test (14565,)

# %% [markdown]
# Building a knn model on a training dataset using hamming distance (Standardized Data)

# %%
knn_classification = KNeighborsClassifier(n_neighbors = 3, metric='hamming')

# %%
knn_model = knn_classification.fit(X_train_norm, y_train)

# %%
#building a confusion matrix
from matplotlib.colors import ListedColormap
plot_confusion_matrix(knn_model, test_data = X_test_norm)

# %%
#Calculate performance measures on the test set.
test_report = get_test_report(knn_model, test_data = X_test_norm)

# print the performace measures
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      5871
#            1       0.89      0.88      0.88      8694
#
#     accuracy                           0.86     14565
#    macro avg       0.86      0.86      0.86     14565
# weighted avg       0.86      0.86      0.86     14565

# %%
plot_roc(knn_model, test_data = X_test_norm)

# %% [markdown]
# Optimal Value of K (using GridSearchCV)

# %%
# create a dictionary with hyperparameters and its values
# n_neighnors: number of neighbors to consider
# usually, we consider the odd value of 'n_neighnors' to avoid the equal number of nearest points with more than one class
# pass the different distance metrics to the parameter, 'metric'
tuned_paramaters = {'n_neighbors': np.arange(2, 25, 1),
                   'metric': ['hamming','euclidean','manhattan','Chebyshev']}
 
# instantiate the 'KNeighborsClassifier' 
knn_classification = KNeighborsClassifier()

# use GridSearchCV() to find the optimal value of the hyperparameters
# estimator: pass the knn model
# param_grid: pass the dictionary with hyperparameters and its values
# cv: number of folds in k-fold i.e. here cv = 5
# scoring: pass the scoring parameter 'accuracy'
knn_grid = GridSearchCV(estimator = knn_classification, 
                        param_grid = tuned_paramaters, 
                        cv = 5, 
                        scoring = 'accuracy')

# fit the model on X_train and y_train using fit()
knn_grid.fit(X_train_norm, y_train)

# get the best parameters
print('Best parameters for KNN Classifier: ', knn_grid.best_params_, '\n')
# Out:
# Best parameters for KNN Classifier:  {'metric': 'hamming', 'n_neighbors': 3}

# %%
print('Classification Report for test set: \n', get_test_report(knn_grid, test_data=X_test_norm))
# Out:
# Classification Report for test set:
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      5871
#            1       0.89      0.88      0.88      8694
#
#     accuracy                           0.86     14565
#    macro avg       0.86      0.86      0.86     14565
# weighted avg       0.86      0.86      0.86     14565

# %%
plot_roc(knn_grid, test_data=X_test_norm)

# %% [markdown]
# #Naive Bayes

# %%
# instantiate the 'GaussianNB'
gnb = GaussianNB()

# fit the model using fit() on train data
gnb_model = gnb.fit(X_train_norm, y_train)

# %%
# call the function to plot the confusion matrix
# pass the gaussian naive bayes model to the function
plot_confusion_matrix(gnb_model, test_data=X_test_norm)

# %%
# compute the performance measures on test data
# call the function 'get_test_report'
# pass the gaussian naive bayes model to the function
test_report = get_test_report(gnb_model, test_data=X_test_norm)

# print the performace measures
print(test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.23      0.32      5871
#            1       0.63      0.89      0.74      8694
#
#     accuracy                           0.62     14565
#    macro avg       0.60      0.56      0.53     14565
# weighted avg       0.61      0.62      0.57     14565

# %%
# call the function to plot the ROC curve
# pass the gaussian naive bayes model to the function
plot_roc(gnb_model, test_data=X_test_norm)

# %% [markdown]
# ###Comparison between KNN Model and Naive Bayes Model

# %%
# K Nearest Neighbors
y_pred_prob_knn = knn_grid.predict_proba(X_test_norm)[:,1]
    
# the roc_curve() returns the values for false positive rate, true positive rate and threshold
# pass the actual target values and predicted probabilities to the function
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob_knn)

# add the AUC score to the plot
auc_score_knn = roc_auc_score(y_test, y_pred_prob_knn)

# plot the ROC curve
plt.plot(fpr, tpr, label='KNN Model (AUC Score = %0.4f)' % auc_score_knn)

# Gaussian Naive Bayes
y_pred_prob_gnb = gnb_model.predict_proba(X_test_norm)[:,1]
    
# the roc_curve() returns the values for false positive rate, true positive rate and threshold
# pass the actual target values and predicted probabilities to the function
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob_gnb)

# add the AUC score to the plot
auc_score_gnb = roc_auc_score(y_test, y_pred_prob_gnb)

# plot the ROC curve
plt.plot(fpr, tpr, label='GNB Model (AUC Score = %0.4f)' % auc_score_gnb)

# set limits for x and y axes
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

# plot the straight line showing worst prediction for the model
plt.plot([0, 1], [0, 1],'r--')

# add plot and axes labels
# set text size using 'fontsize'
plt.title('GNB Model Vs. KNN Model', fontsize = 15)
plt.xlabel('False positive rate (1-Specificity)', fontsize = 15)
plt.ylabel('True positive rate (Sensitivity)', fontsize = 15)

# set the position of legend
plt.legend(loc = 'lower right')

# plot the grid
plt.grid(True)
